# %%
file = open('../README.md', 'r')
data = file.read()
print(data)

file.close()
# Out:
# # python-practice

# %%
file = open('iteration.ipynb', 'r')
data = file.read()
print(data)

file.close()
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 84,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "1\n",
#       "2\n",
#       "3\n",
#       "4\n",
#       "5\n",
#       "6\n",
#       "7\n"
#      ]
#     }
#    ],
#    "source": [
#     "a = [1, 2, 3, 4, 5, 6, 7]\n",
#     "\n",
#     "for element in a:\n",
#     "    print(element)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 85,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "number: 273\n",
#       "number: 103\n",
#       "number: 800\n"
#      ]
#     }
#    ],
#    "source": [
#     "numbers = [273, 103, 5, 32, 65, 9, 72, 800, 99]\n",
#     "\n",
#     "for number in numbers:\n",
#     "    if number >= 100:\n",
#     "        print(f'number: {number}')"
#    ]
#   },
#   {
#    "cell_type": "code",
# ...
